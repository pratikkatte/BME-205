# %%
import sys
import math
import random
from collections import Counter


class FastAreader:
    def __init__(self, fname=''):
        '''contructor: saves attribute fname '''

        self.fname = fname
        self.fileH = None

    def doOpen(self):
        if self.fname == '':
            return sys.stdin
        else:
            return open(self.fname)

    def readFasta(self):

        header = ''
        sequence = ''

        with self.doOpen() as self.fileH:

            header = ''
            sequence = ''

            # skip to first fasta header
            line = self.fileH.readline()
            while not line.startswith('>'):
                line = self.fileH.readline()
            header = line[1:].rstrip()

            for line in self.fileH:
                if line.startswith('>'):
                    yield header, sequence
                    header = line[1:].rstrip()
                    sequence = ''
                else:
                    sequence += ''.join(line.rstrip().split()).upper()
        yield header, sequence

class CommandLine():
    """
    Handle the command line, usage and help requests.

    CommandLine uses argparse, now standard in 2.7 and beyond.
    it implements a standard command line argument parser with various argument options,
    a standard usage and help, and an error termination mechanism do-usage_and_die.

    attributes:
    all arguments received from the commandline using .add_argument will be
    available within the .args attribute of object instantiated from CommandLine.
    For example, if myCommandLine is an object of the class, and requiredbool was
    set as an option using add_argument, then myCommandLine.args.requiredbool will
    name that option.

    """

    def __init__(self, inOpts=None):
        """
        CommandLine constructor.
        There are three arguments that are passed to the class Consensus():
            -i iterations (int)
            -k motif length (int)
            -p pseudocount (float)
        """
        import argparse
        self.parser = argparse.ArgumentParser(
            description='Program prolog - a brief description of what this thing does',
            epilog='Program epilog - some other stuff you feel compelled to say',
            add_help=True,  # default is True
            prefix_chars='-',
            usage='python randomizedMotifSearch.py -i int --maxMotif int --cutoff int < input.fa > output.out'
        )
        # Be sure to go over the argument information again
        self.parser.add_argument('-i', type=int, action='store',
                                 help='number of iterations (int)')
        self.parser.add_argument('-k', type=int, action='store',
                                 help='motif length (int)')
        self.parser.add_argument('-p', type=int, action='store',
                                 help='pseudocount (float)')

        if inOpts is None:
            self.args = self.parser.parse_args()
        else:
            self.args = self.parser.parse_args(inOpts)

class Genome:
    """
    This class helps in initializing and storing different attributes that can be used across several functions across the class. 
    
    """
    def __init__(self, i, k, p, input_sequences):
        """

        """
        self.iterations = i
        self.pseudo_counts = p
        self.kmer_size = k
        self.input_sequences = input_sequences
        self.best_score = 0
        self.best_motif = []
        self.null_distribution = self.null_model_distribution()
        
    def newMotif(self, profile):
        """
        Function: To get new set of motifs from the existing profiles.
        input: profile of a set of existing selected motifs. 
        
        return: new set of motifs that generated using the counts of bases from the profile. 
        """


        new_motif = []
        for seq in self.input_sequences:
            best_prod_score = 0
            best_motif = []

            for i in range(0, len(seq)-self.kmer_size+1):
                motif = seq[i:i+self.kmer_size]
                product_score = 1
                for pos, base in enumerate(motif):
                    count_from_profile = profile[base][pos]
                    product_score = product_score * count_from_profile
                if product_score > best_prod_score:
                    best_prod_score = product_score
                    best_motif = motif
                
            new_motif.append(best_motif)
        
        return new_motif

    def selectRandomKmer(self, input_sequence_list):
        """
        Function: select random kmers from all the reads in the fast file. 
        input: input sequence list from the fasta file.
        
        return: set of random motifs of size k.
        """
        
        rand_kmer_array = []
        
        for sequence in input_sequence_list:
            
            rand_index = random.randint(0, len(sequence)-self.kmer_size)
            
            random_kmer = sequence[rand_index:rand_index+self.kmer_size]
            rand_kmer_array.append(random_kmer)
        return rand_kmer_array
    
    def null_model_distribution(self):
        """
        Function that returns a dictionary of number of counts of every bases {A,C,G,T} in the complete genome sequence.
        """
        input_seq = self.input_sequences
        joined_input_seq = "".join(input_seq)
        col_counter = dict(Counter(joined_input_seq))

        null_distribution = {k: (v+self.pseudo_counts) / (len(joined_input_seq)+ self.pseudo_counts*4) for k, v in col_counter.items()}
        
        return null_distribution


    def make_profile_from_kmers(self, input_motifs):
        """
        The function calculates the distribution of bases for the provided input set of motifs. 

        input: set of motifs of kmer-size k. 
        return: a maxtrix of size 4xk. where the four rows are the bases {A,C,G,T} and the columns of size k each having the counts of bases.
        """
        profile_dict = {
            'A': [],
            'G': [],
            'C': [],
            'T': []
        }

        for i in range(self.kmer_size):
            col = []
            for j in range(len(input_motifs)):
                col.append(input_motifs[j][i])
            col_counter = dict(Counter(col))
            
            nset = len(self.input_sequences)
            profile_dict['A'].append(col_counter['A']+self.pseudo_counts if 'A' in col_counter else 0+self.pseudo_counts)
            profile_dict['C'].append(col_counter['C']+self.pseudo_counts if 'C' in col_counter else 0+self.pseudo_counts)
            profile_dict['T'].append(col_counter['T']+self.pseudo_counts if 'T' in col_counter else 0+self.pseudo_counts)
            profile_dict['G'].append(col_counter['G']+self.pseudo_counts if 'G' in col_counter else 0+self.pseudo_counts)
        return profile_dict
    
    def calcRelativeEntropy(self, input_motifs):
        """
        The function considers the null model and compares it with the experimental model inorder to calculate the relative entropy.
        The function also call the make_profile_from_kmers function to create profile from the provided input set of motifs. 

        Input: the set of motifs of kmer-size k. 

        return: the relative entropy score of the provided set of motifs and the profile of the motifs. 

        """
        relative_motif_score = 0

        profile = self.make_profile_from_kmers(input_motifs)
        for col in range(self.kmer_size):
            for base in self.null_distribution:
                if profile[base][col] != 0: 
                    pr = profile[base][col]/(len(self.input_sequences) + (4*self.pseudo_counts))
                    relative_motif_score += pr * math.log2(pr / self.null_distribution[base])
        return relative_motif_score, profile

    def randomMotifSearch(self, input_seqs):
        """
        The function iterates for self.iterations times and initially selects random motifs of kmers-size k, and creates profile to select the next set of motifs which will be compared with the 
        previous set of motifs using relative entropy score. The process is repeated until the best relative entropy score is found. 

        Input: input sequences of the whole fasta file. 
        return: prints the consensus and the best relative entropy score of the given input. 
        """
        
        for i in range(self.iterations):
            
            random_kmers = self.selectRandomKmer(input_seqs) # initialized kmers randomly with kmer-size -k
            best_score_motif, best_profile = self.calcRelativeEntropy(random_kmers) # calculate the score of the randomly initialized kmers. Consider it as the best_score. 
            selected_motifs = random_kmers
            while True:
                new_motifs = self.newMotif(best_profile) # select new motifs from the current profile
                new_score, new_profile = self.calcRelativeEntropy(new_motifs)
                
                if new_score > best_score_motif:
                    selected_motifs = new_motifs
                    best_score_motif = new_score
                    best_profile = new_profile

                    if best_score_motif > self.best_score:
                        self.best_score = best_score_motif
                        self.best_motif = selected_motifs
                else:
                    break

        print("Found Consencus {} with score - {}".format(self.printConsencus(self.best_motif), self.best_score))

    def printConsencus(self, input_motifs):
        """
        Function: Using the best motif found using randomsearch algorithm, the function returns the consensus from the profile of the motif. 

        Input: input_motif - is the best motif found from the randmom search algorithm.

        return: the consensus motif of kmer-size k. 
        """
        motif_set = input_motifs
        profile = self.make_profile_from_kmers(motif_set)
        concensus = ''
        for i in range(self.kmer_size):
            max_prob = 0
            max_base = 'A'
            for base, probs in profile.items():
                if probs[i] > max_prob:
                    max_prob = probs[i]
                    max_base = base
            concensus+= max_base
        return concensus

def main(inFile="", options = None):
    ''' Setup necessary objects, read data and print the final report.'''
    cl = CommandLine() # setup the command line
    sourceReader = FastAreader() # setup the Fasta reader Object
    sequenceList = []
    for head, seq in sourceReader.readFasta():       # reading the fast file. 
        sequenceList.append(seq)
    
    thisGenome = Genome(cl.args.i, cl.args.k, cl.args.p, sequenceList)
    thisGenome.randomMotifSearch(sequenceList)

if __name__ == "__main__":
    main()
# Out:
# col_counter {'A': 233, 'C': 107, 'G': 26, 'T': 34}
# N 400
# null distributions {'A': 0.5792079207920792, 'C': 0.26732673267326734, 'G': 0.06683168316831684, 'T': 0.08663366336633663}
# 0
# ['AGACGAAAAACTT', 'AACCTACAAAAAA', 'ACTTAAAAACCCA', 'TAAAAACCCACAA', 'AAGAGCAAAAACC', 'TTATAAAAGAGCA', 'ATTTATAAAAGAG', 'ACCGCAAAAACCA']
# 1
# ['ACAGACGAAAAAC', 'AAAACCAGCCCCA', 'CCACAAAAACCAT', 'CACAAGAAAAACT', 'GAAACATTTATAA', 'CATTTATAAAAGA', 'AAAGAGCAAAAAC', 'AAACTTAAAAACA']
# 2
# ['AAACAATCAAAAC', 'AACCTACAAAAAA', 'ACCATCAAAACCA', 'ACTTAAAAACCCA', 'CAAATAAAAACCC', 'CAAAATCCCAAAT', 'AAGAGCAAAAACT', 'ACAAAAACCGCAA']
# 3
# ['ATCAAAACCAGCC', 'AAAAACCCACAAA', 'CAAAAAGCAGACG', 'AAACTTAAAAACC', 'AAAATCCCAAATA', 'AAAACCAAAATCC', 'AGCAAAAACTAAG', 'ACGAAAAACTTAA']
# 4
# ['AAAACTTAAAAAC', 'ACCCACAAAAACC', 'GCAGACGAAAAAC', 'AAGAAAAACTTAA', 'ACCAAAATCCCAA', 'ATTTATAAAAGAG', 'AAACTAAGATCCC', 'AAACACACAAAAA']
# 5
# ['ACTTAAAAACCCA', 'ACCTACAAAAAAC', 'ACAAAAACCATCA', 'ATGACCAGGAACC', 'TTTATAAAAGAGC', 'ACCAAAATCCCAA', 'CATTTATAAAAGA', 'CCGCAAAAACCAG']
# 6
# ['TTAAAAACCCACA', 'CCACAAAAACCAA', 'CCATCAAAACCAG', 'ACTTAAAAACCCA', 'ACATTTATAAAAG', 'AAACATTTATAAA', 'AAGAGCAAAAACT', 'TTAAAAACACACA']
# 7
# ['ACAGACGAAAAAC', 'CTTAAAAACCCAC', 'GCAGACGAAAAAC', 'ACAAAAAACCATG', 'AGCAAAAACCAAA', 'AATCCCAAATAAA', 'AACTAAGATCCCA', 'CGAAAAACTTAAA']
# 21
# ['AACAATCAAAACC', 'AAAAACCAACAAA', 'AAAAACTTAAAAA', 'ATGACCAGGAACC', 'AAAAGAGCAAAAA', 'CAAAAACCAAAAT', 'CTAAGATCCCAAA', 'AACACACAAAAAC']
# 22
# ['ACAAAAACAATCA', 'CAACAAAACCAGC', 'CACAAAAACCATC', 'GAAAAACTTAAAA', 'AGAGCAAAAACCA', 'AAGAGCAAAAACC', 'ACATTTATAAAAG', 'AAAACACACAAAA']
# 23
# ['AAAAACAGACGAA', 'AAAACCAGCCCCA', 'ACCATCAAAACCA', 'TTAAAAACCCACA', 'ATAAAAACCCACA', 'AAGAGCAAAAACC', 'CGAAACATTTATA', 'AACAGACGAAAAA']
# 24
# ['AAACAGACGAAAA', 'CTTAAAAACCCAC', 'AAGCAGACGAAAA', 'CACAAGAAAAACT', 'AAAACCAAAATCC', 'ACATTTATAAAAG', 'CCCAAATAAAAAC', 'AACTTAAAAACAC']
# 25
# ['CTTAAAAACCCAC', 'ACCAACAAAACCA', 'AAAAACTTAAAAA', 'ATGACCAGGAACC', 'TTATAAAAGAGCA', 'AATAAAAACCCAC', 'AATAAAAACCCAC', 'AAAAACCGCAAAA']
# 26
# ['AACTTAAAAACCC', 'AACCAACAAAACC', 'CCCACAAAAACCA', 'ACTTAAAAACCCA', 'ATTTATAAAAGAG', 'ATTTATAAAAGAG', 'AAGATCCCAAATA', 'AAACACACAAAAA']
# 27
# ['CACAAAAACAATC', 'CAAAAACCAACAA', 'ACAAAAACCATCA', 'ACAAGAAAAACTT', 'ATTTATAAAAGAG', 'AACATTTATAAAA', 'CTAAGATCCCAAA', 'AAAACACACAAAA']
# 28
# ['CAGACGAAAAACT', 'TTAAAAACCCACA', 'GAAAAACTTAAAA', 'ACTTAAAAACCCA', 'CAAATAAAAACCC', 'AAATCCCAAATAA', 'TTATAAAAGAGCA', 'CACAAAAACCGCA']
# 29
# ['GAAAAACTTAAAA', 'AAAAACCCACAAA', 'ACAAAAACCATCA', 'TAAAAACCCACAA', 'ACATTTATAAAAG', 'AAATCCCAAATAA', 'AAATAAAAACCCA', 'CAGACGAAAAACT']
# 30
# ['AAACAGACGAAAA', 'AACAAAACCAGCC', 'CAAAAAGCAGACG', 'AAGAAAAACTTAA', 'AGAGCAAAAACCA', 'ATAAAAGAGCAAA', 'TAAGATCCCAAAT', 'AAAACCGCAAAAA']
# 31
# ['AAAAACAATCAAA', 'ACTTAAAAACCCA', 'ACCCACAAAAACC', 'ACAAGAAAAACTT', 'ATAAAAGAGCAAA', 'ACCAAAATCCCAA', 'CGAAACATTTATA', 'ACACACAAAAACC']
# 32
# ['ACTTAAAAACCCA', 'AAACCAACAAAAC', 'CTTAAAAACCCAC', 'AAAAACCATGACC', 'AAATAAAAACCCA', 'TCCCAAATAAAAA', 'TATAAAAGAGCAA', 'AAAAACTTAAAAA']
# 33
# ['TTAAAAACCCACA', 'ACTTAAAAACCCA', 'AAAGCAGACGAAA', 'ACCAGGAACCCCA', 'CAAATAAAAACCC', 'AACATTTATAAAA', 'AAAAACTAAGATC', 'AAACAGACGAAAA']
# 34
# ['AAACAGACGAAAA', 'AAAACCAGCCCCA', 'CAAAAACCATCAA', 'CCATGACCAGGAA', 'CCAAATAAAAACC', 'ATAAAAGAGCAAA', 'AACATTTATAAAA', 'AAACCGCAAAAAC']
# 35
# ['ACAGACGAAAAAC', 'AAACTTAAAAACC', 'AAGCAGACGAAAA', 'CAAGAAAAACTTA', 'AGAGCAAAAACCA', 'CCAAAATCCCAAA', 'TTTATAAAAGAGC', 'CGCAAAAACCAGC']
# 36
# ['AACTTAAAAACCC', 'AAAACCAGCCCCA', 'AAAAGCAGACGAA', 'AAGAAAAACTTAA', 'CAAAATCCCAAAT', 'ATAAAAACCCACA', 'AATAAAAACCCAC', 'AACCGCAAAAACC']
# 37
# ['AAAAACCCACAAA', 'TAAAAACCCACAA', 'AAAAACTTAAAAA', 'ACCCACAAAAAAC', 'AGAGCAAAAACCA', 'GAGCAAAAACCAA', 'CTAAGATCCCAAA', 'GACGAAAAACTTA']
# 38
# ['TAAAAACCCACAA', 'AAACCAACAAAAC', 'TAAAAACCCACAA', 'CAAGAAAAACTTA', 'CGAAACATTTATA', 'AATCCCAAATAAA', 'AATAAAAACCCAC', 'CAGACGAAAAACT']
# 39
# ['AACAGACGAAAAA', 'AACAAAACCAGCC', 'AAAAACTTAAAAA', 'CCATGACCAGGAA', 'GAGCAAAAACCAA', 'TTATAAAAGAGCA', 'AAACTAAGATCCC', 'AACAGACGAAAAA']
# 40
# ['AACTTAAAAACCC', 'CCACAAAAACCAA', 'CTTAAAAACCCAC', 'AAACTTAAAAACC', 'AAATCCCAAATAA', 'CAAATAAAAACCC', 'CAAAAACTAAGAT', 'AACCGCAAAAACC']
# 41
# ['AAAAAACAGACGA', 'ACAAAACCAGCCC', 'TTAAAAACCCACA', 'AGAAAAACTTAAA', 'TTATAAAAGAGCA', 'GAGCAAAAACCAA', 'TTTATAAAAGAGC', 'CAGACGAAAAACT']
# 42
# ['CAATCAAAACCAG', 'AAAAACTTAAAAA', 'ACTTAAAAACCCA', 'AAACCCACAAAAA', 'AAAGAGCAAAAAC', 'AAAACCAAAATCC', 'AAAGAGCAAAAAC', 'ACTTAAAAACACA']
# 43
# ['AAACAATCAAAAC', 'ACCAACAAAACCA', 'AACTTAAAAACCC', 'ACAAGAAAAACTT', 'CATTTATAAAAGA', 'AAAATCCCAAATA', 'AGCAAAAACTAAG', 'AAAACAGACGAAA']
# 44
# ['AAAAAACAGACGA', 'ACCCACAAAAACC', 'AGACGAAAAACTT', 'AAAAACCCACAAA', 'ATAAAAGAGCAAA', 'AAATCCCAAATAA', 'AAATAAAAACCCA', 'CACAAAAACCGCA']
# 45
# ['CAATCAAAACCAG', 'AAACCTACAAAAA', 'CAGACGAAAAACT', 'CAAGAAAAACTTA', 'TATAAAAGAGCAA', 'CAAATAAAAACCC', 'AAACATTTATAAA', 'AACACACAAAAAC']
# 46
# 59
# ['AAAAACCCACAAA', 'AAACCAACAAAAC', 'CACAAAAACCATC', 'AAAACCATGACCA', 'AAAGAGCAAAAAC', 'CCCAAATAAAAAC', 'ATCCCAAATAAAA', 'CGAAAAACTTAAA']
# 60
# ['ACAGACGAAAAAC', 'AAAACCCACAAAA', 'AAAACCATCAAAA', 'CCCACAAAAAACC', 'CATTTATAAAAGA', 'AGAGCAAAAACCA', 'CAAAAACTAAGAT', 'AAACTTAAAAACA']
# 61
# ['AAAAACTTAAAAA', 'AAAAACTTAAAAA', 'AAAAAGCAGACGA', 'CACAAGAAAAACT', 'AGAGCAAAAACCA', 'ATCCCAAATAAAA', 'ACATTTATAAAAG', 'CAAAAACCGCAAA']
# 62
# ['CCACAAAAACAAT', 'CAAAACCAGCCCC', 'GAAAAACTTAAAA', 'ACAAAAAACCATG', 'TCCCAAATAAAAA', 'CCAAAATCCCAAA', 'AGAGCAAAAACTA', 'ACGAAAAACTTAA']
# 63
# ['AAAAAACAGACGA', 'ACAAAAAACTTAA', 'CCACAAAAACCAT', 'TTAAAAACCCACA', 'TAAAAGAGCAAAA', 'CCAAATAAAAACC', 'GATCCCAAATAAA', 'AAACAGACGAAAA']
# 64
# ['CAATCAAAACCAG', 'TTAAAAACCCACA', 'CAGACGAAAAACT', 'AAACCATGACCAG', 'TTATAAAAGAGCA', 'AATCCCAAATAAA', 'CCAAATAAAAACC', 'CCGCAAAAACCAG']
# 65
# ['AAAAACCCACAAA', 'AAAACCAACAAAA', 'AAAACCATCAAAA', 'AAAAACCATGACC', 'AAATAAAAACCCA', 'AAATCCCAAATAA', 'ATAAAAGAGCAAA', 'AAAAACCGCAAAA']
# 66
# ['ACAAAAACAATCA', 'TAAAAACCCACAA', 'AAACTTAAAAACC', 'AAAACCCACAAAA', 'CCAAATAAAAACC', 'TCCCAAATAAAAA', 'AGAGCAAAAACTA', 'CTTAAAAACACAC']
# 67
# ['ACAAAAACAATCA', 'CTACAAAAAACTT', 'CTTAAAAACCCAC', 'TAAAAACCCACAA', 'AGCAAAAACCAAA', 'AAAACCAAAATCC', 'AAAAACTAAGATC', 'ACCGCAAAAACCA']
# 68
# ['ACAGACGAAAAAC', 'AAAAAACTTAAAA', 'GACGAAAAACTTA', 'TTAAAAACCCACA', 'ACCAAAATCCCAA', 'TATAAAAGAGCAA', 'AAAGAGCAAAAAC', 'AACAGACGAAAAA']
# 69
# ['CCACAAAAACAAT', 'CAAAAACCAACAA', 'AAAAACCCACAAA', 'ATGACCAGGAACC', 'AATCCCAAATAAA', 'CAAAATCCCAAAT', 'AACATTTATAAAA', 'AAAACTTAAAAAC']
# 70
# ['CCACAAAAACAAT', 'CACAAAAACCAAC', 'CATCAAAACCAGC', 'ACACAAGAAAAAC', 'AATAAAAACCCAC', 'ACCAAAATCCCAA', 'ATCCCAAATAAAA', 'AAAAAACAGACGA']
# 71
# ['AAACCCACAAAAA', 'AAACCCACAAAAA', 'AACCCACAAAAAC', 'AAAAAACCATGAC', 'CAAATAAAAACCC', 'CAAATAAAAACCC', 'AAGAGCAAAAACT', 'AAAACCGCAAAAA']
# ['AAAAACCCACAAA', 'ACAAAAAACTTAA', 'ACGAAAAACTTAA', 'CCCACAAAAAACC', 'CAAAATCCCAAAT', 'TCCCAAATAAAAA', 'GCAAAAACTAAGA', 'CACACAAAAACCG']
# 111
# ['CAATCAAAACCAG', 'ACCTACAAAAAAC', 'ACAAAAACCATCA', 'AAGAAAAACTTAA', 'AAAAACCAAAATC', 'GAGCAAAAACCAA', 'AAAAACTAAGATC', 'AGACGAAAAACTT']
# 112
# ['CCCACAAAAACAA', 'CCAACAAAACCAG', 'CAAAAAGCAGACG', 'ATGACCAGGAACC', 'AATCCCAAATAAA', 'CAAAATCCCAAAT', 'AACATTTATAAAA', 'AAAAACTTAAAAA']
# 113
# ['AACAATCAAAACC', 'CCACAAAAACCAA', 'AAAAACCATCAAA', 'AAAACCATGACCA', 'AACATTTATAAAA', 'AAAGAGCAAAAAC', 'AGCAAAAACTAAG', 'CCGCAAAAACCAG']
# 114
# ['GACGAAAAACTTA', 'AAAACCCACAAAA', 'CACAAAAACCATC', 'ACCATGACCAGGA', 'TTTATAAAAGAGC', 'GAAACATTTATAA', 'AGAGCAAAAACTA', 'CGAAAAACTTAAA']
# 115
# ['TAAAAACCCACAA', 'ACAAAACCAGCCC', 'CAAAAAGCAGACG', 'TGACCAGGAACCC', 'CAAAATCCCAAAT', 'CATTTATAAAAGA', 'AAGAGCAAAAACT', 'AGACGAAAAACTT']
# 116
# ['CAAAAACAATCAA', 'CAAAAAACTTAAA', 'GACGAAAAACTTA', 'ACCATGACCAGGA', 'GCAAAAACCAAAA', 'CCCAAATAAAAAC', 'AGCAAAAACTAAG', 'ACACAAAAACCGC']
# 117
# ['AAAAACAATCAAA', 'AACCAACAAAACC', 'AAACTTAAAAACC', 'AAACCATGACCAG', 'AAATAAAAACCCA', 'TATAAAAGAGCAA', 'ACTAAGATCCCAA', 'AAAAACTTAAAAA']
# 118
# ['AAACAATCAAAAC', 'AAAAAACTTAAAA', 'AAGCAGACGAAAA', 'AAAACCCACAAAA', 'CAAAATCCCAAAT', 'AAAACCAAAATCC', 'CCCAAATAAAAAC', 'CTTAAAAACACAC']
# 119
# ['AAAAAACAGACGA', 'AAAACCCACAAAA', 'TTAAAAACCCACA', 'ACCAGGAACCCCA', 'ATAAAAACCCACA', 'TCCCAAATAAAAA', 'TATAAAAGAGCAA', 'ACAAAAACCGCAA']
# 120
# ['ACAATCAAAACCA', 'AACCAACAAAACC', 'AAAACCCACAAAA', 'CCCACAAAAAACC', 'AAATAAAAACCCA', 'CAAATAAAAACCC', 'ACTAAGATCCCAA', 'CAAAAACCGCAAA']
# 121
# ['AAAAACCCACAAA', 'AACTTAAAAACCC', 'AAACTTAAAAACC', 'GACCAGGAACCCC', 'ACCAAAATCCCAA', 'AAGAGCAAAAACC', 'TAAGATCCCAAAT', 'AAAACAGACGAAA']
# 122
# ['AAAAACCCACAAA', 'AACCAACAAAACC', 'AACCCACAAAAAC', 'ACAAAAAACCATG', 'TATAAAAGAGCAA', 'TCCCAAATAAAAA', 'AAACATTTATAAA', 'GACGAAAAACTTA']
# 123
# ['AAACAATCAAAAC', 'AAAACCAGCCCCA', 'AAAAACCCACAAA', 'AGAAAAACTTAAA', 'AAATCCCAAATAA', 'ATTTATAAAAGAG', 'CCAAATAAAAACC', 'CAAAAACCGCAAA']
# 124
# ['AAAAAACAGACGA', 'AAAAACTTAAAAA', 'CCCACAAAAACCA', 'AAAACTTAAAAAC', 'ACATTTATAAAAG', 'ATCCCAAATAAAA', 'GAGCAAAAACTAA', 'AAAACACACAAAA']
# 125
# ['CCCACAAAAACAA', 'TACAAAAAACTTA', 'AAAAACCCACAAA', 'ATGACCAGGAACC', 'ACCAAAATCCCAA', 'AAAAACCAAAATC', 'TCCCAAATAAAAA', 'ACCGCAAAAACCA']
# 126
# ['AAAACAGACGAAA', 'CTACAAAAAACTT', 'AAACTTAAAAACC', 'AAACCCACAAAAA', 'AAGAGCAAAAACC', 'CATTTATAAAAGA', 'AAGATCCCAAATA', 'CAGACGAAAAACT']
# 127
# ['CAGACGAAAAACT', 'AAAACCAACAAAA', 'ACGAAAAACTTAA', 'AACCCACAAAAAA', 'GAAACATTTATAA', 'AAACATTTATAAA', 'AAAAACTAAGATC', 'AAACAGACGAAAA']
# 128
# ['TTAAAAACCCACA', 'CCCACAAAAACCA', 'AAACCCACAAAAA', 'AAAAACCATGACC', 'TATAAAAGAGCAA', 'AGAGCAAAAACCA', 'CCAAATAAAAACC', 'ACACAAAAACCGC']
# 129
# ['AATCAAAACCAGC', 'AAACTTAAAAACC', 'ACGAAAAACTTAA', 'AACTTAAAAACCC', 'CATTTATAAAAGA', 'ACCAAAATCCCAA', 'AGAGCAAAAACTA', 'AAAACCGCAAAAA']
# 130
# ['ATCAAAACCAGCC', 'AAAAACTTAAAAA', 'AAAACTTAAAAAC', 'AAACCATGACCAG', 'GAGCAAAAACCAA', 'AATCCCAAATAAA', 'GAGCAAAAACTAA', 'AAAAAACAGACGA']
# 131
# ['CAAAAACAATCAA', 'AAAACCCACAAAA', 'AACCATCAAAACC', 'AAACTTAAAAACC', 'ACATTTATAAAAG', 'AAATCCCAAATAA', 'AAACTAAGATCCC', 'GCAAAAACCAGCC']
# 132
# ['TAAAAACCCACAA', 'AAAAACCAACAAA', 'AACTTAAAAACCC', 'AAACCATGACCAG', 'CAAAAACCAAAAT', 'AAAAGAGCAAAAA', 'ACTAAGATCCCAA', 'AAAAACCGCAAAA']
# 133
# ['CAGACGAAAAACT', 'TTAAAAACCCACA', 'AACCCACAAAAAC', 'GACCAGGAACCCC', 'AAACCAAAATCCC', 'AATAAAAACCCAC', 'GCAAAAACTAAGA', 'TTAAAAACACACA']
# 134
# ['AAAAACAGACGAA', 'ACAAAAACCAACA', 'ACTTAAAAACCCA', 'TACACAAGAAAAA', 'AATAAAAACCCAC', 'AACATTTATAAAA', 'TCCCAAATAAAAA', 'TTAAAAACACACA']
# 135
# ['AAACTTAAAAACC', 'CCCACAAAAACCA', 'AAAACTTAAAAAC', 'ACTTAAAAACCCA', 'GAGCAAAAACCAA', 'TTATAAAAGAGCA', 'ATTTATAAAAGAG', 'AAAACAGACGAAA']
# 136
# ['TAAAAACCCACAA', 'AAAACCAACAAAA', 'AAAAGCAGACGAA', 'ACCAGGAACCCCA', 'AACCAAAATCCCA', 'TTATAAAAGAGCA', 'CATTTATAAAAGA', 'TTAAAAACACACA']
# 137
# ['AAAAACCCACAAA', 'CAAAAACCAACAA', 'CGAAAAACTTAAA', 'ACTTAAAAACCCA', 'TTATAAAAGAGCA', 'CAAATAAAAACCC', 'AACTAAGATCCCA', 'AACCGCAAAAACC']
# 138
# ['AAACAATCAAAAC', 'AAAAACCCACAAA', 'ACGAAAAACTTAA', 'AAAAACCCACAAA', 'ATCCCAAATAAAA', 'GCAAAAACCAAAA', 'AAAACTAAGATCC', 'AGACGAAAAACTT']
# 139
# ['CAAAAACAATCAA', 'CTACAAAAAACTT', 'GACGAAAAACTTA', 'TTAAAAACCCACA', 'CCAAAATCCCAAA', 'AAATAAAAACCCA', 'AACTAAGATCCCA', 'ACAGACGAAAAAC']
# 140
# ['CCCACAAAAACAA', 'AAACCTACAAAAA', 'AACTTAAAAACCC', 'ATGACCAGGAACC', 'TTTATAAAAGAGC', 'AATCCCAAATAAA', 'AACTAAGATCCCA', 'ACTTAAAAACACA']
# 141
# ['ATCAAAACCAGCC', 'CACAAAAACCAAC', 'AAACCCACAAAAA', 'AGAAAAACTTAAA', 'AAGAGCAAAAACC', 'ATCCCAAATAAAA', 'GAAACATTTATAA', 'CCGCAAAAACCAG']
# 142
# ['AAAAACCCACAAA', 'CTTAAAAACCCAC', 'AAGCAGACGAAAA', 'AAACCATGACCAG', 'CAAAAACCAAAAT', 'CAAAATCCCAAAT', 'TTTATAAAAGAGC', 'GACGAAAAACTTA']
# 143
# ['AAAACAGACGAAA', 'ACCTACAAAAAAC', 'TTAAAAACCCACA', 'ACCATGACCAGGA', 'TTTATAAAAGAGC', 'ATTTATAAAAGAG', 'AGAGCAAAAACTA', 'ACCGCAAAAACCA']
# 144
# ['GACGAAAAACTTA', 'CACAAAAACCAAC', 'ACAAAAACCATCA', 'CACAAAAAACCAT', 'CAAATAAAAACCC', 'CAAAATCCCAAAT', 'ATAAAAACCCACA', 'ACGAAAAACTTAA']
# 145
# ['CCACAAAAACAAT', 'ACAAAAAACTTAA', 'AAAAACCATCAAA', 'AAAAAACCATGAC', 'AGCAAAAACCAAA', 'AAACATTTATAAA', 'AACTAAGATCCCA', 'AAAACTTAAAAAC']
# 146
# ['ACAAAAACAATCA', 'AAAACCAACAAAA', 'AAACTTAAAAACC', 'CACAAAAAACCAT', 'ATTTATAAAAGAG', 'AACCAAAATCCCA', 'CAAATAAAAACCC', 'AAACACACAAAAA']
# 147
# ['AAACAGACGAAAA', 'ACAAAAACCAACA', 'ACTTAAAAACCCA', 'ACTTAAAAACCCA', 'TTTATAAAAGAGC', 'AATCCCAAATAAA', 'CATTTATAAAAGA', 'AAAACTTAAAAAC']
# 148
# ['CAATCAAAACCAG', 'CCTACAAAAAACT', 'CATCAAAACCAGC', 'TGACCAGGAACCC', 'AAATAAAAACCCA', 'AAAACCAAAATCC', 'TTTATAAAAGAGC', 'ACACAAAAACCGC']
# 162
# ['AAACCCACAAAAA', 'AAAAACCAACAAA', 'AAAGCAGACGAAA', 'AAACCCACAAAAA', 'CAAAAACCAAAAT', 'AAACCAAAATCCC', 'ATTTATAAAAGAG', 'CGCAAAAACCAGC']
# 163
# ['AAACAATCAAAAC', 'ACTTAAAAACCCA', 'GACGAAAAACTTA', 'AACCATGACCAGG', 'AAGAGCAAAAACC', 'ATTTATAAAAGAG', 'AAACTAAGATCCC', 'CCGCAAAAACCAG']
# 164
# ['AACCCACAAAAAC', 'CAAAAAACTTAAA', 'ACTTAAAAACCCA', 'GACCAGGAACCCC', 'AAGAGCAAAAACC', 'AAAATCCCAAATA', 'AAATAAAAACCCA', 'CCGCAAAAACCAG']
# 165
# ['AAAAACAGACGAA', 'AAAAACCCACAAA', 'AAAAAGCAGACGA', 'AACTTAAAAACCC', 'AGCAAAAACCAAA', 'CAAAAACCAAAAT', 'AAAACTAAGATCC', 'AAACACACAAAAA']
# 166
# ['AAAAAACAGACGA', 'AAACTTAAAAACC', 'GACGAAAAACTTA', 'GACCAGGAACCCC', 'CCAAAATCCCAAA', 'ACATTTATAAAAG', 'TATAAAAGAGCAA', 'AAAAACAGACGAA']
# 167
# ['ACAGACGAAAAAC', 'CAACAAAACCAGC', 'AAAAACTTAAAAA', 'ACAAAAAACCATG', 'CAAAATCCCAAAT', 'AATCCCAAATAAA', 'AAAACTAAGATCC', 'CGAAAAACTTAAA']
# 168
# ['AACCCACAAAAAC', 'AAACCCACAAAAA', 'TAAAAACCCACAA', 'GACCAGGAACCCC', 'CATTTATAAAAGA', 'AACATTTATAAAA', 'TATAAAAGAGCAA', 'CGAAAAACTTAAA']
# 169
# ['AAACAGACGAAAA', 'TACAAAAAACTTA', 'ACTTAAAAACCCA', 'AAAACCATGACCA', 'AAAATCCCAAATA', 'TCCCAAATAAAAA', 'AGATCCCAAATAA', 'ACACAAAAACCGC']
# 170
# ['CTTAAAAACCCAC', 'ACTTAAAAACCCA', 'AAAACCATCAAAA', 'GAAAAACTTAAAA', 'AAACCAAAATCCC', 'AAAATCCCAAATA', 'TTTATAAAAGAGC', 'TTAAAAACACACA']
# 171
# ['ATCAAAACCAGCC', 'ACCAACAAAACCA', 'AAACCATCAAAAC', 'AACCCACAAAAAA', 'AAACATTTATAAA', 'AAGAGCAAAAACC', 'CTAAGATCCCAAA', 'AAACAGACGAAAA']
# 172
# ['AAAAAACAGACGA', 'ACTTAAAAACCCA', 'TTAAAAACCCACA', 'CTTAAAAACCCAC', 'TTATAAAAGAGCA', 'GAGCAAAAACCAA', 'GCAAAAACTAAGA', 'AAAAACACACAAA']
# 173
# ['AGACGAAAAACTT', 'AAACCTACAAAAA', 'AAAAACCATCAAA', 'AAAAACCATGACC', 'TAAAAGAGCAAAA', 'TTATAAAAGAGCA', 'ACTAAGATCCCAA', 'ACCGCAAAAACCA']
# 174
# 187
# ['ACAGACGAAAAAC', 'CCAACAAAACCAG', 'CGAAAAACTTAAA', 'CACAAGAAAAACT', 'AGAGCAAAAACCA', 'AAATCCCAAATAA', 'AGATCCCAAATAA', 'AACCGCAAAAACC']
# 188
# ['AACAATCAAAACC', 'AAAACTTAAAAAC', 'AAACCCACAAAAA', 'CACAAAAAACCAT', 'GCAAAAACCAAAA', 'ACCAAAATCCCAA', 'TAAGATCCCAAAT', 'AAAACACACAAAA']
# 189
# ['AAACAGACGAAAA', 'ACCCACAAAAACC', 'AAGCAGACGAAAA', 'CCCACAAAAAACC', 'ATTTATAAAAGAG', 'AAATAAAAACCCA', 'ACTAAGATCCCAA', 'TTAAAAACACACA']
# 190
# ['ACTTAAAAACCCA', 'AAAAACTTAAAAA', 'AAAAACCCACAAA', 'AAGAAAAACTTAA', 'ATAAAAACCCACA', 'TATAAAAGAGCAA', 'AAACTAAGATCCC', 'TAAAAACACACAA']
# 191
# ['CCCACAAAAACAA', 'AAAAAACTTAAAA', 'AGCAGACGAAAAA', 'AACCCACAAAAAA', 'AAATAAAAACCCA', 'ACCAAAATCCCAA', 'AAAACTAAGATCC', 'GACGAAAAACTTA']
# 192
# ['AACAATCAAAACC', 'TACAAAAAACTTA', 'CCACAAAAACCAT', 'CCATGACCAGGAA', 'AACCAAAATCCCA', 'GAAACATTTATAA', 'AACTAAGATCCCA', 'TAAAAACACACAA']
# 193
# ['GAAAAACTTAAAA', 'ACTTAAAAACCCA', 'AAAAACCCACAAA', 'ACCATGACCAGGA', 'AAAAGAGCAAAAA', 'AAGAGCAAAAACC', 'TTATAAAAGAGCA', 'ACGAAAAACTTAA']
# 194
# ['AACAGACGAAAAA', 'AAAACCCACAAAA', 'GCAGACGAAAAAC', 'CCATGACCAGGAA', 'CAAATAAAAACCC', 'CCAAATAAAAACC', 'AAACATTTATAAA', 'AAAACACACAAAA']
# 195
# ['GACGAAAAACTTA', 'CACAAAAACCAAC', 'GACGAAAAACTTA', 'AAACTTAAAAACC', 'TAAAAGAGCAAAA', 'ATAAAAGAGCAAA', 'AGATCCCAAATAA', 'AAAACAGACGAAA']
# 196
# ['CCACAAAAACAAT', 'CCACAAAAACCAA', 'AAACTTAAAAACC', 'AAAACCATGACCA', 'GCAAAAACCAAAA', 'AAATCCCAAATAA', 'AAGAGCAAAAACT', 'ACCGCAAAAACCA']
# 197
# ['AACTTAAAAACCC', 'AAACCCACAAAAA', 'CAAAAACCATCAA', 'ACTTAAAAACCCA', 'AACCAAAATCCCA', 'AATAAAAACCCAC', 'AGATCCCAAATAA', 'CAAAAACCGCAAA']
# 198
# ['TTAAAAACCCACA', 'CACAAAAACCAAC', 'AAAACCATCAAAA', 'CATGACCAGGAAC', 'CAAAATCCCAAAT', 'ATAAAAGAGCAAA', 'AAAAGAGCAAAAA', 'GACGAAAAACTTA']
# 199
# ['ACTTAAAAACCCA', 'CCTACAAAAAACT', 'CAAAAACCATCAA', 'CACAAAAAACCAT', 'AAATAAAAACCCA', 'ATTTATAAAAGAG', 'CCAAATAAAAACC', 'AGACGAAAAACTT']
# 200
# ['TTAAAAACCCACA', 'TACAAAAAACTTA', 'ACGAAAAACTTAA', 'AAAACCCACAAAA', 'AAATCCCAAATAA', 'CCCAAATAAAAAC', 'TATAAAAGAGCAA', 'CACAAAAACCGCA']
# 201
# ['ACAGACGAAAAAC', 'CTTAAAAACCCAC', 'CACAAAAACCATC', 'CCACAAAAAACCA', 'GAAACATTTATAA', 'CAAAATCCCAAAT', 'AACATTTATAAAA', 'CACACAAAAACCG']
# 202
# ['AAACAATCAAAAC', 'CCACAAAAACCAA', 'AAACTTAAAAACC', 'ACAAAAAACCATG', 'CATTTATAAAAGA', 'AACCAAAATCCCA', 'AAGAGCAAAAACT', 'AAAAACAGACGAA']
# 203
# ['AAAAACCCACAAA', 'ACAAAAAACTTAA', 'AAAAACCCACAAA', 'AAAACTTAAAAAC', 'TTATAAAAGAGCA', 'AAACATTTATAAA', 'GCAAAAACTAAGA', 'AAAAACCGCAAAA']
# 204
# ['GACGAAAAACTTA', 'AACCAACAAAACC', 'CACAAAAACCATC', 'TACACAAGAAAAA', 'CATTTATAAAAGA', 'GAAACATTTATAA', 'GAGCAAAAACTAA', 'AAAACTTAAAAAC']
# 205
# ['ACGAAAAACTTAA', 'ACAAAACCAGCCC', 'AAACCATCAAAAC', 'AAAAACCATGACC', 'TTTATAAAAGAGC', 'GCAAAAACCAAAA', 'AGAGCAAAAACTA', 'TAAAAACACACAA']
# 206
# ['AGACGAAAAACTT', 'CCTACAAAAAACT', 'AAACTTAAAAACC', 'AAAAAACCATGAC', 'AATCCCAAATAAA', 'ACATTTATAAAAG', 'TTTATAAAAGAGC', 'AAAACCGCAAAAA']
# 207
# ['ACAATCAAAACCA', 'AACCTACAAAAAA', 'AAAACCATCAAAA', 'GACCAGGAACCCC', 'AGAGCAAAAACCA', 'TATAAAAGAGCAA', 'GCAAAAACTAAGA', 'CACAAAAACCGCA']
# 208
# ['AAAAAACAGACGA', 'CCCACAAAAACCA', 'AAACTTAAAAACC', 'GACCAGGAACCCC', 'CAAAATCCCAAAT', 'TAAAAGAGCAAAA', 'CATTTATAAAAGA', 'AACCGCAAAAACC']
# 209
# ['AACCCACAAAAAC', 'CTACAAAAAACTT', 'AAACCATCAAAAC', 'ATGACCAGGAACC', 'CCCAAATAAAAAC', 'CCCAAATAAAAAC', 'AAATAAAAACCCA', 'AAAAACAGACGAA']
# 210
# ['ACCCACAAAAACA', 'AACCAACAAAACC', 'AAAAGCAGACGAA', 'ACAAAAAACCATG', 'AACCAAAATCCCA', 'GAGCAAAAACCAA', 'GAAACATTTATAA', 'AAACACACAAAAA']
# 211
# ['AACAGACGAAAAA', 'CCCACAAAAACCA', 'AAACTTAAAAACC', 'AGAAAAACTTAAA', 'ATAAAAACCCACA', 'AAAACCAAAATCC', 'TTATAAAAGAGCA', 'AAAACAGACGAAA']
# 212
# ['AAACCCACAAAAA', 'AACAAAACCAGCC', 'AAAAACCCACAAA', 'AACTTAAAAACCC', 'AATCCCAAATAAA', 'ATCCCAAATAAAA', 'TAAAAGAGCAAAA', 'GACGAAAAACTTA']
# ['CAATCAAAACCAG', 'CAAAAAACTTAAA', 'AACTTAAAAACCC', 'AAAAACCCACAAA', 'AAATCCCAAATAA', 'AAAGAGCAAAAAC', 'GCAAAAACTAAGA', 'AAAACCGCAAAAA']
# 226
# ['AAAAACTTAAAAA', 'CAAAAAACTTAAA', 'AGACGAAAAACTT', 'CAAGAAAAACTTA', 'AAATCCCAAATAA', 'TAAAAGAGCAAAA', 'AGATCCCAAATAA', 'ACAGACGAAAAAC']
# 227
# ['AAAAACCCACAAA', 'CCCACAAAAACCA', 'AAGCAGACGAAAA', 'TGACCAGGAACCC', 'CAAATAAAAACCC', 'GCAAAAACCAAAA', 'CAAAAACTAAGAT', 'CGAAAAACTTAAA']
# 228
# ['GAAAAACTTAAAA', 'CCACAAAAACCAA', 'AAAACCATCAAAA', 'TTAAAAACCCACA', 'TTTATAAAAGAGC', 'AAAAGAGCAAAAA', 'TTATAAAAGAGCA', 'AACTTAAAAACAC']
# 229
# ['AAAACAATCAAAA', 'AACCTACAAAAAA', 'AAACCCACAAAAA', 'TGACCAGGAACCC', 'AATAAAAACCCAC', 'AACCAAAATCCCA', 'GATCCCAAATAAA', 'CCGCAAAAACCAG']
# 230
# ['GACGAAAAACTTA', 'TACAAAAAACTTA', 'AAGCAGACGAAAA', 'AACCCACAAAAAA', 'CCAAAATCCCAAA', 'ATCCCAAATAAAA', 'CCAAATAAAAACC', 'ACACAAAAACCGC']
# 231
# ['CCACAAAAACAAT', 'CAAAACCAGCCCC', 'AAGCAGACGAAAA', 'AAAAACTTAAAAA', 'AAAAACCAAAATC', 'ACATTTATAAAAG', 'AGATCCCAAATAA', 'CAAAAACCGCAAA']
# 232
# ['AACAATCAAAACC', 'CCCACAAAAACCA', 'AGACGAAAAACTT', 'TGACCAGGAACCC', 'ATAAAAACCCACA', 'TAAAAGAGCAAAA', 'TTATAAAAGAGCA', 'CACAAAAACCGCA']
# 233
# ['AAACAATCAAAAC', 'CCTACAAAAAACT', 'CAGACGAAAAACT', 'CATGACCAGGAAC', 'TATAAAAGAGCAA', 'CAAAAACCAAAAT', 'ATAAAAGAGCAAA', 'CGAAAAACTTAAA']
# 234
# ['AAAAACCCACAAA', 'CTTAAAAACCCAC', 'AAAACCCACAAAA', 'CATGACCAGGAAC', 'GCAAAAACCAAAA', 'CATTTATAAAAGA', 'GAGCAAAAACTAA', 'AAAAACTTAAAAA']
# 235
# ['CAATCAAAACCAG', 'AAAAACCCACAAA', 'AGACGAAAAACTT', 'AACCCACAAAAAA', 'CAAATAAAAACCC', 'CATTTATAAAAGA', 'CCCAAATAAAAAC', 'CGAAAAACTTAAA']
# 236
# ['ATCAAAACCAGCC', 'AAAACCAGCCCCA', 'GACGAAAAACTTA', 'AAACTTAAAAACC', 'AAAACCAAAATCC', 'AATAAAAACCCAC', 'AAACATTTATAAA', 'AAAAACAGACGAA']
# 237
# ['ACAGACGAAAAAC', 'ACCTACAAAAAAC', 'CCATCAAAACCAG', 'AAAAACCCACAAA', 'AAAGAGCAAAAAC', 'AATAAAAACCCAC', 'TAAGATCCCAAAT', 'AAAAACAGACGAA']
# 238
# 251
# ['CCCACAAAAACAA', 'CCAACAAAACCAG', 'AAAAGCAGACGAA', 'CACAAGAAAAACT', 'AAACATTTATAAA', 'TTATAAAAGAGCA', 'AAAACTAAGATCC', 'AAAAACCGCAAAA']
# 252
# ['AACAATCAAAACC', 'AAACCAACAAAAC', 'GACGAAAAACTTA', 'CCATGACCAGGAA', 'TTATAAAAGAGCA', 'AAAAACCAAAATC', 'AAAAACTAAGATC', 'CGAAAAACTTAAA']
# 253
# ['CCCACAAAAACAA', 'AAACCCACAAAAA', 'CATCAAAACCAGC', 'CCCACAAAAAACC', 'CCCAAATAAAAAC', 'CCCAAATAAAAAC', 'CAAATAAAAACCC', 'AAAACCGCAAAAA']
# 254
# ['AATCAAAACCAGC', 'AAACCCACAAAAA', 'CAAAAACCATCAA', 'ACACAAGAAAAAC', 'AACCAAAATCCCA', 'AAAACCAAAATCC', 'TTTATAAAAGAGC', 'ACACAAAAACCGC']
# 255
# ['ATCAAAACCAGCC', 'AAACCCACAAAAA', 'AAAAAGCAGACGA', 'AACCATGACCAGG', 'GAGCAAAAACCAA', 'ATAAAAACCCACA', 'AATAAAAACCCAC', 'AAACTTAAAAACA']
# 256
# ['AAACAGACGAAAA', 'AAAACCAGCCCCA', 'CAAAAACCATCAA', 'AAACTTAAAAACC', 'CCAAATAAAAACC', 'ACCAAAATCCCAA', 'TATAAAAGAGCAA', 'AACTTAAAAACAC']
# 257
# ['AAAACAGACGAAA', 'CAAAACCAGCCCC', 'CAGACGAAAAACT', 'ACTTAAAAACCCA', 'GAAACATTTATAA', 'AAATCCCAAATAA', 'AAAAACTAAGATC', 'ACACAAAAACCGC']
# 258
# ['ACGAAAAACTTAA', 'CAAAAACCAACAA', 'AAAAACTTAAAAA', 'AAAAAACCATGAC', 'CCCAAATAAAAAC', 'ATCCCAAATAAAA', 'AACATTTATAAAA', 'GACGAAAAACTTA']
# 259
# ['AACAATCAAAACC', 'ACTTAAAAACCCA', 'ACCATCAAAACCA', 'ACCCACAAAAAAC', 'ATCCCAAATAAAA', 'CCAAATAAAAACC', 'ACTAAGATCCCAA', 'AAAAACACACAAA']
# 260
# ['GAAAAACTTAAAA', 'AAACCAACAAAAC', 'AACCATCAAAACC', 'CCCACAAAAAACC', 'CAAATAAAAACCC', 'AAACCAAAATCCC', 'GAGCAAAAACTAA', 'AAAAACCGCAAAA']
# 261
# ['AAAAACTTAAAAA', 'TTAAAAACCCACA', 'ACTTAAAAACCCA', 'TGACCAGGAACCC', 'CAAAAACCAAAAT', 'AAGAGCAAAAACC', 'CAAAAACTAAGAT', 'TTAAAAACACACA']
# 262
# ['AAAACTTAAAAAC', 'ACCAACAAAACCA', 'TAAAAACCCACAA', 'AACCATGACCAGG', 'AAACCAAAATCCC', 'AAATAAAAACCCA', 'AGCAAAAACTAAG', 'TTAAAAACACACA']
# 263
# ['AGACGAAAAACTT', 'CAAAACCAGCCCC', 'AACCATCAAAACC', 'ACAAAAAACCATG', 'CCAAAATCCCAAA', 'AAACCAAAATCCC', 'TATAAAAGAGCAA', 'TTAAAAACACACA']
# ['AACTTAAAAACCC', 'AAAACCAACAAAA', 'ACTTAAAAACCCA', 'CCCACAAAAAACC', 'CAAAAACCAAAAT', 'ATAAAAACCCACA', 'AATAAAAACCCAC', 'AAAAAACAGACGA']
# 277
# ['ACTTAAAAACCCA', 'CCACAAAAACCAA', 'AAACTTAAAAACC', 'ACAAGAAAAACTT', 'TTTATAAAAGAGC', 'AATCCCAAATAAA', 'CAAAAACTAAGAT', 'CGAAAAACTTAAA']
# 278
# ['CCCACAAAAACAA', 'CCAACAAAACCAG', 'TTAAAAACCCACA', 'GAAAAACTTAAAA', 'GCAAAAACCAAAA', 'AACCAAAATCCCA', 'AAGAGCAAAAACT', 'AAACTTAAAAACA']
# 279
# ['GACGAAAAACTTA', 'AACCAACAAAACC', 'GACGAAAAACTTA', 'AAACCATGACCAG', 'AACCAAAATCCCA', 'CAAAATCCCAAAT', 'AAATAAAAACCCA', 'AAAAACCGCAAAA']
# 280
# ['ACAATCAAAACCA', 'ACTTAAAAACCCA', 'AAACTTAAAAACC', 'AAGAAAAACTTAA', 'CCAAATAAAAACC', 'AAATCCCAAATAA', 'CCAAATAAAAACC', 'AACACACAAAAAC']
# 281
# ['AACAGACGAAAAA', 'CAAAACCAGCCCC', 'CAGACGAAAAACT', 'ACAAGAAAAACTT', 'AAATAAAAACCCA', 'CCCAAATAAAAAC', 'AAAAGAGCAAAAA', 'CGCAAAAACCAGC']
# 282
# ['ACAATCAAAACCA', 'AAAAACTTAAAAA', 'ACGAAAAACTTAA', 'ACCCACAAAAAAC', 'CCAAATAAAAACC', 'AAATCCCAAATAA', 'TTTATAAAAGAGC', 'AAAACTTAAAAAC']
# 283
# ['ATCAAAACCAGCC', 'ACCAACAAAACCA', 'AGCAGACGAAAAA', 'CCATGACCAGGAA', 'AAATCCCAAATAA', 'AACATTTATAAAA', 'GATCCCAAATAAA', 'GACGAAAAACTTA']
# 284
# ['AAACAATCAAAAC', 'CAAAAACCAACAA', 'ACAAAAACCATCA', 'GACCAGGAACCCC', 'AACATTTATAAAA', 'AAATAAAAACCCA', 'GATCCCAAATAAA', 'TAAAAACACACAA']
# 285
# ['AAAAACAGACGAA', 'ACAAAAACCAACA', 'AACTTAAAAACCC', 'TACACAAGAAAAA', 'AAAGAGCAAAAAC', 'ATAAAAACCCACA', 'ACATTTATAAAAG', 'AAAACAGACGAAA']
# 286
# ['CACAAAAACAATC', 'CCCACAAAAACCA', 'AAGCAGACGAAAA', 'ATGACCAGGAACC', 'AACATTTATAAAA', 'ACATTTATAAAAG', 'ATCCCAAATAAAA', 'AAAACAGACGAAA']
# 287
# ['TTAAAAACCCACA', 'CAAAAACCAACAA', 'CGAAAAACTTAAA', 'AAAAACTTAAAAA', 'CAAAATCCCAAAT', 'AACCAAAATCCCA', 'ACTAAGATCCCAA', 'ACAAAAACCGCAA']
# 288
# ['ACCCACAAAAACA', 'CACAAAAACCAAC', 'AGCAGACGAAAAA', 'ATGACCAGGAACC', 'TTATAAAAGAGCA', 'AAACCAAAATCCC', 'TTTATAAAAGAGC', 'GAAAAACTTAAAA']
# 289
# ['ACAATCAAAACCA', 'ACAAAAACCAACA', 'AAACCATCAAAAC', 'AAAAACTTAAAAA', 'AAGAGCAAAAACC', 'CGAAACATTTATA', 'GAAACATTTATAA', 'TAAAAACACACAA']
# 290
# ['CAAAAACAATCAA', 'AACAAAACCAGCC', 'CCACAAAAACCAT', 'ATGACCAGGAACC', 'ACCAAAATCCCAA', 'AAGAGCAAAAACC', 'AGAGCAAAAACTA', 'CAAAAACCGCAAA']
# 291
# ['AAACCCACAAAAA', 'AAAAACTTAAAAA', 'ACTTAAAAACCCA', 'ACTTAAAAACCCA', 'TTTATAAAAGAGC', 'AAACATTTATAAA', 'TAAGATCCCAAAT', 'AAAAACAGACGAA']
# 292
# ['AACTTAAAAACCC', 'ACTTAAAAACCCA', 'AAGCAGACGAAAA', 'AGAAAAACTTAAA', 'AAACATTTATAAA', 'AAATCCCAAATAA', 'AACATTTATAAAA', 'AACTTAAAAACAC']
# 293
# ['AAAACAGACGAAA', 'ACAAAAACCAACA', 'CACAAAAACCATC', 'TTAAAAACCCACA', 'CAAATAAAAACCC', 'AAAGAGCAAAAAC', 'AACATTTATAAAA', 'GACGAAAAACTTA']
# 294
# ['AAACAATCAAAAC', 'AAAACCCACAAAA', 'AAAACTTAAAAAC', 'GACCAGGAACCCC', 'AAAAACCAAAATC', 'AATAAAAACCCAC', 'AAAAACTAAGATC', 'AACTTAAAAACAC']
# 295
# ['TAAAAACCCACAA', 'AAAAACTTAAAAA', 'AAACCATCAAAAC', 'TTAAAAACCCACA', 'CAAAATCCCAAAT', 'CAAAAACCAAAAT', 'AGCAAAAACTAAG', 'AAACAGACGAAAA']
# 296
# ['CAATCAAAACCAG', 'AAAACCAGCCCCA', 'CGAAAAACTTAAA', 'AAAAACCATGACC', 'AAATAAAAACCCA', 'TCCCAAATAAAAA', 'AACATTTATAAAA', 'AAACACACAAAAA']
# 297
# ['ACCCACAAAAACA', 'CAACAAAACCAGC', 'TAAAAACCCACAA', 'AAAAAACCATGAC', 'CAAAATCCCAAAT', 'TATAAAAGAGCAA', 'CAAAAACTAAGAT', 'ACACACAAAAACC']
# 298
# ['GAAAAACTTAAAA', 'AACAAAACCAGCC', 'CAAAAACCATCAA', 'TAAAAACCCACAA', 'AAGAGCAAAAACC', 'CAAAAACCAAAAT', 'TATAAAAGAGCAA', 'CAAAAACCGCAAA']
# 299
# ['AAACAGACGAAAA', 'ACAAAACCAGCCC', 'CCCACAAAAACCA', 'AAAAAACCATGAC', 'AAATAAAAACCCA', 'CCAAATAAAAACC', 'TTATAAAAGAGCA', 'ACACACAAAAACC']
# 300
# ['AACTTAAAAACCC', 'TAAAAACCCACAA', 'AAAAACTTAAAAA', 'CCCACAAAAAACC', 'CATTTATAAAAGA', 'AAATCCCAAATAA', 'AACTAAGATCCCA', 'ACAGACGAAAAAC']
# 301
# ['ACAATCAAAACCA', 'AACTTAAAAACCC', 'AAAGCAGACGAAA', 'AAAACCCACAAAA', 'ACCAAAATCCCAA', 'AAACATTTATAAA', 'ACATTTATAAAAG', 'AAAAACTTAAAAA']
# 302
# 315
# ['CAGACGAAAAACT', 'CAACAAAACCAGC', 'GACGAAAAACTTA', 'TAAAAACCCACAA', 'AAAAGAGCAAAAA', 'CCAAATAAAAACC', 'GAGCAAAAACTAA', 'AAACACACAAAAA']
# 316
# ['CTTAAAAACCCAC', 'ACAAAAACCAACA', 'AGCAGACGAAAAA', 'CACAAAAAACCAT', 'CCAAAATCCCAAA', 'AATCCCAAATAAA', 'AATAAAAACCCAC', 'AACTTAAAAACAC']
# 317
# ['AAACTTAAAAACC', 'AAACCCACAAAAA', 'AGCAGACGAAAAA', 'CACAAGAAAAACT', 'CATTTATAAAAGA', 'CCAAAATCCCAAA', 'ACTAAGATCCCAA', 'ACACACAAAAACC']
# 318
# ['CAATCAAAACCAG', 'AACCAACAAAACC', 'AAAGCAGACGAAA', 'TACACAAGAAAAA', 'ATAAAAGAGCAAA', 'CATTTATAAAAGA', 'TCCCAAATAAAAA', 'CACAAAAACCGCA']
# 319
# ['AAAACCCACAAAA', 'CAAAACCAGCCCC', 'GCAGACGAAAAAC', 'CATGACCAGGAAC', 'AAACATTTATAAA', 'AAGAGCAAAAACC', 'AAAGAGCAAAAAC', 'CGCAAAAACCAGC']
# 320
# ['AAAAACAATCAAA', 'AAAAACCCACAAA', 'AAAAGCAGACGAA', 'CAAGAAAAACTTA', 'AGCAAAAACCAAA', 'CAAATAAAAACCC', 'AATAAAAACCCAC', 'AAAACAGACGAAA']
# 321
# ['GAAAAACTTAAAA', 'AACCCACAAAAAC', 'AAAAAGCAGACGA', 'CTTAAAAACCCAC', 'ATAAAAACCCACA', 'TATAAAAGAGCAA', 'CTAAGATCCCAAA', 'AACAGACGAAAAA']
# 322
# ['TAAAAACCCACAA', 'AAAACTTAAAAAC', 'CCATCAAAACCAG', 'TAAAAACCCACAA', 'AATAAAAACCCAC', 'ACCAAAATCCCAA', 'CAAATAAAAACCC', 'AAAACACACAAAA']
# 323
# ['ACCCACAAAAACA', 'AAAAAACTTAAAA', 'AGCAGACGAAAAA', 'CCATGACCAGGAA', 'AAACCAAAATCCC', 'AACATTTATAAAA', 'ATTTATAAAAGAG', 'CACAAAAACCGCA']
# 324
# ['AAACTTAAAAACC', 'CTACAAAAAACTT', 'AAAAACCCACAAA', 'CAAAAAACCATGA', 'AAAAACCAAAATC', 'GAAACATTTATAA', 'AGCAAAAACTAAG', 'ACAAAAACCGCAA']
# 325
# ['AAAACAATCAAAA', 'CTTAAAAACCCAC', 'AAAACCCACAAAA', 'TGACCAGGAACCC', 'ACCAAAATCCCAA', 'AAAATCCCAAATA', 'TAAAAGAGCAAAA', 'GCAAAAACCAGCC']
# 326
# ['ACCCACAAAAACA', 'TACAAAAAACTTA', 'CTTAAAAACCCAC', 'TAAAAACCCACAA', 'ACATTTATAAAAG', 'CATTTATAAAAGA', 'AGCAAAAACTAAG', 'ACGAAAAACTTAA']
# 327
# ['ACCCACAAAAACA', 'AAAAACTTAAAAA', 'AACCCACAAAAAC', 'ACCCACAAAAAAC', 'AACCAAAATCCCA', 'ATTTATAAAAGAG', 'CATTTATAAAAGA', 'AAAAAACAGACGA']
# 328
# ['TAAAAACCCACAA', 'AAAACCAACAAAA', 'AAACCCACAAAAA', 'AAAACCCACAAAA', 'ATTTATAAAAGAG', 'TTATAAAAGAGCA', 'CATTTATAAAAGA', 'GAAAAACTTAAAA']
# 329
# ['CACAAAAACAATC', 'AAAACCAACAAAA', 'ACCATCAAAACCA', 'TGACCAGGAACCC', 'CCCAAATAAAAAC', 'CAAAATCCCAAAT', 'ATTTATAAAAGAG', 'AAAAACAGACGAA']
# 330
# ['ACAGACGAAAAAC', 'CCCACAAAAACCA', 'ACCATCAAAACCA', 'AAGAAAAACTTAA', 'AAAAACCAAAATC', 'ACCAAAATCCCAA', 'CGAAACATTTATA', 'TTAAAAACACACA']
# 331
# ['CCACAAAAACAAT', 'CACAAAAACCAAC', 'AGCAGACGAAAAA', 'TGACCAGGAACCC', 'AGAGCAAAAACCA', 'AATAAAAACCCAC', 'CCAAATAAAAACC', 'CGAAAAACTTAAA']
# 332
# ['ACCCACAAAAACA', 'AAAACTTAAAAAC', 'AGACGAAAAACTT', 'AAAACCCACAAAA', 'CAAAAACCAAAAT', 'AGCAAAAACCAAA', 'TCCCAAATAAAAA', 'ACGAAAAACTTAA']
# 333
# ['AACAGACGAAAAA', 'AAAACTTAAAAAC', 'CCACAAAAACCAT', 'AAAACCCACAAAA', 'CAAAATCCCAAAT', 'CAAAAACCAAAAT', 'ATCCCAAATAAAA', 'AACAGACGAAAAA']
# 334
# ['AACCCACAAAAAC', 'TAAAAACCCACAA', 'AAACTTAAAAACC', 'ACCATGACCAGGA', 'AAAAGAGCAAAAA', 'AATCCCAAATAAA', 'ATTTATAAAAGAG', 'GACGAAAAACTTA']
# 335
# ['TAAAAACCCACAA', 'AAACCTACAAAAA', 'ACCCACAAAAACC', 'CCCACAAAAAACC', 'ACCAAAATCCCAA', 'AAAACCAAAATCC', 'AGATCCCAAATAA', 'AAAACACACAAAA']
# 336
# ['CACAAAAACAATC', 'AAAAAACTTAAAA', 'TTAAAAACCCACA', 'ACCCACAAAAAAC', 'AAAAGAGCAAAAA', 'ATCCCAAATAAAA', 'AAAAACTAAGATC', 'GAAAAACTTAAAA']
# 337
# ['CCCACAAAAACAA', 'AACCCACAAAAAC', 'CTTAAAAACCCAC', 'ACCATGACCAGGA', 'AATAAAAACCCAC', 'AGAGCAAAAACCA', 'AAAAACTAAGATC', 'ACACACAAAAACC']
# 338
# ['CTTAAAAACCCAC', 'ACAAAAACCAACA', 'AAACCCACAAAAA', 'GAAAAACTTAAAA', 'AATAAAAACCCAC', 'AAAAGAGCAAAAA', 'ATAAAAACCCACA', 'ACCGCAAAAACCA']
# 339
# ...
# 887
# ['ATCAAAACCAGCC', 'CCTACAAAAAACT', 'GACGAAAAACTTA', 'ACCCACAAAAAAC', 'AATCCCAAATAAA', 'TTATAAAAGAGCA', 'AAACTAAGATCCC', 'CGAAAAACTTAAA']
# 888
# ['AAACAGACGAAAA', 'AAAAACCCACAAA', 'AAACCCACAAAAA', 'AAAAAACCATGAC', 'AAACCAAAATCCC', 'AACATTTATAAAA', 'GCAAAAACTAAGA', 'TTAAAAACACACA']
# 889
# ['AACAATCAAAACC', 'CTACAAAAAACTT', 'AAAACCATCAAAA', 'ACTTAAAAACCCA', 'TAAAAGAGCAAAA', 'ATTTATAAAAGAG', 'ATAAAAGAGCAAA', 'ACCGCAAAAACCA']
# 890
# ['AAAAACCCACAAA', 'AACCCACAAAAAC', 'TTAAAAACCCACA', 'AAAACCCACAAAA', 'AACCAAAATCCCA', 'ATTTATAAAAGAG', 'CAAATAAAAACCC', 'GCAAAAACCAGCC']
# 891
# ['AAACCCACAAAAA', 'AAAAACTTAAAAA', 'CAAAAAGCAGACG', 'AAAAACTTAAAAA', 'CCAAATAAAAACC', 'GCAAAAACCAAAA', 'AACTAAGATCCCA', 'AAAACCGCAAAAA']
# 892
# ['CCACAAAAACAAT', 'ACCCACAAAAACC', 'ACGAAAAACTTAA', 'AGAAAAACTTAAA', 'AAAGAGCAAAAAC', 'TATAAAAGAGCAA', 'CCCAAATAAAAAC', 'AAACTTAAAAACA']
# 893
# ['AAAAACTTAAAAA', 'ACAAAACCAGCCC', 'AAACCATCAAAAC', 'ATGACCAGGAACC', 'AAATAAAAACCCA', 'TTTATAAAAGAGC', 'TAAGATCCCAAAT', 'CAAAAACCGCAAA']
# 894
# ['AACAGACGAAAAA', 'CAAAAAACTTAAA', 'AGACGAAAAACTT', 'ACACAAGAAAAAC', 'ATCCCAAATAAAA', 'AAACCAAAATCCC', 'CAAAAACTAAGAT', 'AACACACAAAAAC']
# 895
# ['GACGAAAAACTTA', 'AAAACCAACAAAA', 'AAACCATCAAAAC', 'CCCACAAAAAACC', 'TAAAAGAGCAAAA', 'CAAAAACCAAAAT', 'GAAACATTTATAA', 'AGACGAAAAACTT']
# 896
# ['AAACTTAAAAACC', 'AAAAAACTTAAAA', 'GACGAAAAACTTA', 'TTAAAAACCCACA', 'CAAAAACCAAAAT', 'TTATAAAAGAGCA', 'AAAGAGCAAAAAC', 'GACGAAAAACTTA']
# 897
# ['ACAGACGAAAAAC', 'AAAAACCAACAAA', 'CAGACGAAAAACT', 'CAAGAAAAACTTA', 'GAAACATTTATAA', 'ATCCCAAATAAAA', 'AAGATCCCAAATA', 'AAAACAGACGAAA']
# 898
# ['AAAAACTTAAAAA', 'ACAAAAAACTTAA', 'AAAAGCAGACGAA', 'CCATGACCAGGAA', 'ATAAAAACCCACA', 'AACATTTATAAAA', 'ATCCCAAATAAAA', 'AGACGAAAAACTT']
# 899
# ['ACTTAAAAACCCA', 'ACCTACAAAAAAC', 'AAGCAGACGAAAA', 'AACCCACAAAAAA', 'CGAAACATTTATA', 'ATTTATAAAAGAG', 'TTTATAAAAGAGC', 'AAAACTTAAAAAC']
# 900
# ['ATCAAAACCAGCC', 'AACTTAAAAACCC', 'CGAAAAACTTAAA', 'CCACAAAAAACCA', 'GAAACATTTATAA', 'CATTTATAAAAGA', 'TATAAAAGAGCAA', 'CTTAAAAACACAC']
# 901
# ['ATCAAAACCAGCC', 'CCCACAAAAACCA', 'AAAACCCACAAAA', 'AAACTTAAAAACC', 'CCCAAATAAAAAC', 'AGAGCAAAAACCA', 'CCCAAATAAAAAC', 'CGCAAAAACCAGC']
# 902
# ['AACAGACGAAAAA', 'ACAAAAAACTTAA', 'CATCAAAACCAGC', 'TACACAAGAAAAA', 'CCAAATAAAAACC', 'AAAGAGCAAAAAC', 'AAAAGAGCAAAAA', 'TTAAAAACACACA']
# 903
# ['CGAAAAACTTAAA', 'AACAAAACCAGCC', 'CAAAAAGCAGACG', 'AGAAAAACTTAAA', 'AAAGAGCAAAAAC', 'CCCAAATAAAAAC', 'ATCCCAAATAAAA', 'AACACACAAAAAC']
# 904
# ['ATCAAAACCAGCC', 'AAACTTAAAAACC', 'CACAAAAACCATC', 'AGAAAAACTTAAA', 'TAAAAGAGCAAAA', 'AAACCAAAATCCC', 'ACTAAGATCCCAA', 'CACAAAAACCGCA']
# 905
# ['AAAACTTAAAAAC', 'CCAACAAAACCAG', 'AAAACTTAAAAAC', 'AAAAAACCATGAC', 'TTTATAAAAGAGC', 'AAAAACCAAAATC', 'TTTATAAAAGAGC', 'CAAAAACCGCAAA']
# 906
# ['AGACGAAAAACTT', 'CAACAAAACCAGC', 'AGACGAAAAACTT', 'ACCATGACCAGGA', 'AACCAAAATCCCA', 'GCAAAAACCAAAA', 'AAATAAAAACCCA', 'AAAACAGACGAAA']
# 907
# ['ACAGACGAAAAAC', 'AACCCACAAAAAC', 'AAAAACCATCAAA', 'GAAAAACTTAAAA', 'ACCAAAATCCCAA', 'GCAAAAACCAAAA', 'GATCCCAAATAAA', 'TAAAAACACACAA']
# 908
# ['ACAAAAACAATCA', 'CTTAAAAACCCAC', 'ACCATCAAAACCA', 'AAAAAACCATGAC', 'GCAAAAACCAAAA', 'AAAATCCCAAATA', 'AAAAGAGCAAAAA', 'AACAGACGAAAAA']
# 909
# ['AAAAACAATCAAA', 'CCACAAAAACCAA', 'CGAAAAACTTAAA', 'TACACAAGAAAAA', 'TCCCAAATAAAAA', 'ATTTATAAAAGAG', 'CTAAGATCCCAAA', 'ACAAAAACCGCAA']
# 910
# ['AACAATCAAAACC', 'TACAAAAAACTTA', 'CAGACGAAAAACT', 'AAAACTTAAAAAC', 'CCAAAATCCCAAA', 'CCAAAATCCCAAA', 'ATAAAAACCCACA', 'CAGACGAAAAACT']
# 911
# ['CGAAAAACTTAAA', 'CTACAAAAAACTT', 'AAACCCACAAAAA', 'ACTTAAAAACCCA', 'AAAACCAAAATCC', 'AAAAGAGCAAAAA', 'CTAAGATCCCAAA', 'AGACGAAAAACTT']
# 912
# ['AAACTTAAAAACC', 'AAAAACCAACAAA', 'AAAAACCATCAAA', 'AAAACCCACAAAA', 'ATAAAAACCCACA', 'ATAAAAACCCACA', 'AGCAAAAACTAAG', 'CACACAAAAACCG']
# 913
# ['AAACCCACAAAAA', 'AACCAACAAAACC', 'ACCCACAAAAACC', 'ACCATGACCAGGA', 'CCCAAATAAAAAC', 'AGCAAAAACCAAA', 'TATAAAAGAGCAA', 'CAAAAACCGCAAA']
# 914
# ['CAGACGAAAAACT', 'CAAAAAACTTAAA', 'AACTTAAAAACCC', 'ACCATGACCAGGA', 'TCCCAAATAAAAA', 'AAGAGCAAAAACC', 'TTATAAAAGAGCA', 'AAAAACAGACGAA']
# 915
# ['CAGACGAAAAACT', 'CCTACAAAAAACT', 'AAGCAGACGAAAA', 'ACCATGACCAGGA', 'GAAACATTTATAA', 'TAAAAGAGCAAAA', 'ACTAAGATCCCAA', 'AAAAACACACAAA']
# 916
# ['ACGAAAAACTTAA', 'AAACCCACAAAAA', 'GCAGACGAAAAAC', 'CAAGAAAAACTTA', 'CCAAATAAAAACC', 'TCCCAAATAAAAA', 'GATCCCAAATAAA', 'AAAAACTTAAAAA']
# 917
# ['TTAAAAACCCACA', 'ACCAACAAAACCA', 'AAAAACCATCAAA', 'CCATGACCAGGAA', 'GAGCAAAAACCAA', 'CAAATAAAAACCC', 'AAAACTAAGATCC', 'ACCGCAAAAACCA']
# 918
# ['ACAATCAAAACCA', 'AACCTACAAAAAA', 'AAAAGCAGACGAA', 'AAAAACCATGACC', 'TTTATAAAAGAGC', 'ACCAAAATCCCAA', 'AGATCCCAAATAA', 'AAAAACACACAAA']
# 919
# ['ACCCACAAAAACA', 'AAAACCAACAAAA', 'ACAAAAACCATCA', 'CACAAGAAAAACT', 'AAACATTTATAAA', 'TAAAAGAGCAAAA', 'AAATAAAAACCCA', 'TAAAAACACACAA']
# 920
# ['CGAAAAACTTAAA', 'ACCAACAAAACCA', 'CCACAAAAACCAT', 'AAAAACTTAAAAA', 'CAAAAACCAAAAT', 'ACCAAAATCCCAA', 'TCCCAAATAAAAA', 'AGACGAAAAACTT']
# 921
# ['AATCAAAACCAGC', 'ACCAACAAAACCA', 'ACCATCAAAACCA', 'ATGACCAGGAACC', 'AATAAAAACCCAC', 'ATCCCAAATAAAA', 'ATCCCAAATAAAA', 'CCGCAAAAACCAG']
# 922
# ['CGAAAAACTTAAA', 'CCAACAAAACCAG', 'AAAGCAGACGAAA', 'CAAAAAACCATGA', 'GAGCAAAAACCAA', 'TCCCAAATAAAAA', 'ATAAAAACCCACA', 'ACACACAAAAACC']
# 923
# ['AAACCCACAAAAA', 'AAAACCCACAAAA', 'TAAAAACCCACAA', 'ACAAGAAAAACTT', 'GAAACATTTATAA', 'ATAAAAACCCACA', 'AAACATTTATAAA', 'GACGAAAAACTTA']
# 924
# ['AACCCACAAAAAC', 'CCCACAAAAACCA', 'CATCAAAACCAGC', 'ACACAAGAAAAAC', 'AAAACCAAAATCC', 'ACCAAAATCCCAA', 'ATTTATAAAAGAG', 'CACAAAAACCGCA']
# 925
# ['AAACCCACAAAAA', 'CCCACAAAAACCA', 'CCCACAAAAACCA', 'CCACAAAAAACCA', 'AACATTTATAAAA', 'AGAGCAAAAACCA', 'AGAGCAAAAACTA', 'AACTTAAAAACAC']
# 926
# ['TAAAAACCCACAA', 'AAAACCAGCCCCA', 'AGCAGACGAAAAA', 'CAAGAAAAACTTA', 'CAAAAACCAAAAT', 'TTTATAAAAGAGC', 'AAAACTAAGATCC', 'CGAAAAACTTAAA']
# 927
# ['AAAAACAGACGAA', 'AACAAAACCAGCC', 'TAAAAACCCACAA', 'CACAAGAAAAACT', 'AATCCCAAATAAA', 'AAAATCCCAAATA', 'AATAAAAACCCAC', 'AAACCGCAAAAAC']
# 928
# ['CCACAAAAACAAT', 'AAAAACCCACAAA', 'AAAAAGCAGACGA', 'AACCATGACCAGG', 'ATAAAAACCCACA', 'GAAACATTTATAA', 'AAAAACTAAGATC', 'ACACACAAAAACC']
# 929
# ['AATCAAAACCAGC', 'CACAAAAACCAAC', 'TAAAAACCCACAA', 'GACCAGGAACCCC', 'ATTTATAAAAGAG', 'TCCCAAATAAAAA', 'ATTTATAAAAGAG', 'AAAACTTAAAAAC']
# 930
# ['AAAACCCACAAAA', 'ACCAACAAAACCA', 'AAAACCATCAAAA', 'CCCACAAAAAACC', 'ATAAAAGAGCAAA', 'CAAAAACCAAAAT', 'AACTAAGATCCCA', 'CACAAAAACCGCA']
# 931
# ['AAAAACTTAAAAA', 'ACCAACAAAACCA', 'AAGCAGACGAAAA', 'ATGACCAGGAACC', 'AAAGAGCAAAAAC', 'GCAAAAACCAAAA', 'GAGCAAAAACTAA', 'AAACAGACGAAAA']
# 932
# ['TAAAAACCCACAA', 'CAAAACCAGCCCC', 'ACCCACAAAAACC', 'TTAAAAACCCACA', 'CATTTATAAAAGA', 'ATAAAAACCCACA', 'ATTTATAAAAGAG', 'GCAAAAACCAGCC']
# 933
# ['AAAACCCACAAAA', 'AAAAACCCACAAA', 'AAGCAGACGAAAA', 'GACCAGGAACCCC', 'CCAAATAAAAACC', 'ATCCCAAATAAAA', 'AAGATCCCAAATA', 'AAAACTTAAAAAC']
# 934
# ['AAACCCACAAAAA', 'CTACAAAAAACTT', 'TTAAAAACCCACA', 'CCATGACCAGGAA', 'CAAAAACCAAAAT', 'AAAATCCCAAATA', 'CAAATAAAAACCC', 'AAAAACACACAAA']
# 935
# ['AAAAACTTAAAAA', 'CAAAAACCAACAA', 'ACCCACAAAAACC', 'AAAAACCCACAAA', 'CCCAAATAAAAAC', 'AATCCCAAATAAA', 'AAATAAAAACCCA', 'GAAAAACTTAAAA']
# 936
# ['AAAAACAGACGAA', 'CAACAAAACCAGC', 'CGAAAAACTTAAA', 'GACCAGGAACCCC', 'TCCCAAATAAAAA', 'AAAGAGCAAAAAC', 'GATCCCAAATAAA', 'CTTAAAAACACAC']
# 937
# ['ACAATCAAAACCA', 'AAAAACCAACAAA', 'CCATCAAAACCAG', 'ACAAGAAAAACTT', 'CCAAATAAAAACC', 'AAAAGAGCAAAAA', 'AACTAAGATCCCA', 'CAAAAACCGCAAA']
# 938
# ['ACGAAAAACTTAA', 'TTAAAAACCCACA', 'GACGAAAAACTTA', 'AACCCACAAAAAA', 'AAAATCCCAAATA', 'CAAAATCCCAAAT', 'AAAAACTAAGATC', 'AACAGACGAAAAA']
# 939
# ['AAAACTTAAAAAC', 'CAAAAACCAACAA', 'ACTTAAAAACCCA', 'AAACCCACAAAAA', 'ATAAAAGAGCAAA', 'GAGCAAAAACCAA', 'AGAGCAAAAACTA', 'CACACAAAAACCG']
# 940
# ['AACTTAAAAACCC', 'CAAAAAACTTAAA', 'GACGAAAAACTTA', 'ACTTAAAAACCCA', 'GAAACATTTATAA', 'AGAGCAAAAACCA', 'CAAAAACTAAGAT', 'CAAAAACCGCAAA']
# 941
# ['AAAACAATCAAAA', 'ACAAAACCAGCCC', 'CCACAAAAACCAT', 'AAAAACCATGACC', 'AAACATTTATAAA', 'AAAAGAGCAAAAA', 'ATAAAAGAGCAAA', 'CTTAAAAACACAC']
# 942
# ['GACGAAAAACTTA', 'AACCTACAAAAAA', 'AACTTAAAAACCC', 'AAAACCCACAAAA', 'AAATAAAAACCCA', 'TAAAAGAGCAAAA', 'AAACATTTATAAA', 'AAAACCGCAAAAA']
# 943
# ['AAAAACAGACGAA', 'CCTACAAAAAACT', 'AGCAGACGAAAAA', 'ACCCACAAAAAAC', 'CAAAAACCAAAAT', 'ACATTTATAAAAG', 'TAAGATCCCAAAT', 'AACACACAAAAAC']
# 944
# ['ACAGACGAAAAAC', 'ACAAAAACCAACA', 'AGACGAAAAACTT', 'TAAAAACCCACAA', 'TTTATAAAAGAGC', 'AATAAAAACCCAC', 'CCCAAATAAAAAC', 'AGACGAAAAACTT']
# 945
# ['AACAATCAAAACC', 'AAAACCAGCCCCA', 'AAACCATCAAAAC', 'AAAAACCCACAAA', 'TCCCAAATAAAAA', 'CATTTATAAAAGA', 'AGAGCAAAAACTA', 'AGACGAAAAACTT']
# 946
# ['AAAAACCCACAAA', 'ACCCACAAAAACC', 'CATCAAAACCAGC', 'ACAAAAAACCATG', 'AGAGCAAAAACCA', 'AAAATCCCAAATA', 'AAAGAGCAAAAAC', 'ACGAAAAACTTAA']
# 947
# ['CAGACGAAAAACT', 'AAACTTAAAAACC', 'AAAAACTTAAAAA', 'AAAACCCACAAAA', 'AAATCCCAAATAA', 'CAAAATCCCAAAT', 'GAGCAAAAACTAA', 'GCAAAAACCAGCC']
# 948
# ['AAACAGACGAAAA', 'ACCAACAAAACCA', 'AACCATCAAAACC', 'CACAAAAAACCAT', 'TTTATAAAAGAGC', 'AAAAACCAAAATC', 'CAAATAAAAACCC', 'CACAAAAACCGCA']
# 949
# ['AAAAACAATCAAA', 'TTAAAAACCCACA', 'ACTTAAAAACCCA', 'AAAACTTAAAAAC', 'AACCAAAATCCCA', 'ATCCCAAATAAAA', 'AACTAAGATCCCA', 'TAAAAACACACAA']
# 950
# ['AAAAACAGACGAA', 'ACCTACAAAAAAC', 'AAAGCAGACGAAA', 'TAAAAACCCACAA', 'GAGCAAAAACCAA', 'AAATAAAAACCCA', 'ACTAAGATCCCAA', 'TAAAAACACACAA']
# 951
# ['AACCCACAAAAAC', 'CAAAAAACTTAAA', 'AACCATCAAAACC', 'TAAAAACCCACAA', 'AAATCCCAAATAA', 'ACCAAAATCCCAA', 'CGAAACATTTATA', 'CACACAAAAACCG']
# 952
# ['ACTTAAAAACCCA', 'AAACCCACAAAAA', 'AGCAGACGAAAAA', 'TAAAAACCCACAA', 'CAAAAACCAAAAT', 'AAAGAGCAAAAAC', 'ATAAAAGAGCAAA', 'ACAAAAACCGCAA']
# 953
# ['AAAAACCCACAAA', 'CAAAAACCAACAA', 'AAAAGCAGACGAA', 'AAAACCCACAAAA', 'CATTTATAAAAGA', 'TCCCAAATAAAAA', 'ATCCCAAATAAAA', 'ACACAAAAACCGC']
# 954
# ['AAAACCCACAAAA', 'AAAAACCAACAAA', 'GCAGACGAAAAAC', 'AAACTTAAAAACC', 'GAGCAAAAACCAA', 'CCCAAATAAAAAC', 'ACATTTATAAAAG', 'AAACACACAAAAA']
# 955
# ['CCACAAAAACAAT', 'ACAAAACCAGCCC', 'TAAAAACCCACAA', 'AAACCATGACCAG', 'GAAACATTTATAA', 'AACATTTATAAAA', 'TAAAAGAGCAAAA', 'ACAAAAACCGCAA']
# 956
# ['GACGAAAAACTTA', 'AAACCTACAAAAA', 'ACCCACAAAAACC', 'ACTTAAAAACCCA', 'CAAAAACCAAAAT', 'AAAAACCAAAATC', 'AATAAAAACCCAC', 'ACAGACGAAAAAC']
# 957
# ['AGACGAAAAACTT', 'AAAACTTAAAAAC', 'AAACTTAAAAACC', 'CATGACCAGGAAC', 'TTATAAAAGAGCA', 'CAAAATCCCAAAT', 'AAAAACTAAGATC', 'ACAAAAACCGCAA']
# 958
# ['AAAAACAATCAAA', 'AAAAAACTTAAAA', 'AACTTAAAAACCC', 'AACTTAAAAACCC', 'ATAAAAACCCACA', 'AAAAACCAAAATC', 'GCAAAAACTAAGA', 'AAAAACTTAAAAA']
# 959
# ['ACAGACGAAAAAC', 'CAAAAACCAACAA', 'AAACCCACAAAAA', 'AACTTAAAAACCC', 'CCAAAATCCCAAA', 'ACCAAAATCCCAA', 'AATAAAAACCCAC', 'AAACTTAAAAACA']
# 960
# ['AAAAACAGACGAA', 'AACCTACAAAAAA', 'ACCATCAAAACCA', 'TTAAAAACCCACA', 'CATTTATAAAAGA', 'AATCCCAAATAAA', 'AAAAGAGCAAAAA', 'ACTTAAAAACACA']
# 961
# ['CGAAAAACTTAAA', 'CCTACAAAAAACT', 'ACCCACAAAAACC', 'AAAAACCATGACC', 'GAGCAAAAACCAA', 'TATAAAAGAGCAA', 'CATTTATAAAAGA', 'AACACACAAAAAC']
# 962
# ['CGAAAAACTTAAA', 'CAAAACCAGCCCC', 'CAGACGAAAAACT', 'TACACAAGAAAAA', 'CCAAATAAAAACC', 'AAAATCCCAAATA', 'GATCCCAAATAAA', 'AAAACCGCAAAAA']
# 963
# ['AGACGAAAAACTT', 'CTTAAAAACCCAC', 'AAAAACTTAAAAA', 'ACTTAAAAACCCA', 'AGCAAAAACCAAA', 'GCAAAAACCAAAA', 'TCCCAAATAAAAA', 'ACACACAAAAACC']
# 964
# ['GACGAAAAACTTA', 'AAAAACCAACAAA', 'AAAAACTTAAAAA', 'CTTAAAAACCCAC', 'GCAAAAACCAAAA', 'AAAAGAGCAAAAA', 'TAAGATCCCAAAT', 'GAAAAACTTAAAA']
# 965
# ['CCACAAAAACAAT', 'AAAAACTTAAAAA', 'AAAAAGCAGACGA', 'AAACCCACAAAAA', 'GAGCAAAAACCAA', 'AGAGCAAAAACCA', 'AGATCCCAAATAA', 'AACTTAAAAACAC']
# 966
# ['AACCCACAAAAAC', 'AAAACCAGCCCCA', 'ACAAAAACCATCA', 'AAGAAAAACTTAA', 'CGAAACATTTATA', 'ATCCCAAATAAAA', 'TTATAAAAGAGCA', 'AAAAACACACAAA']
# 967
# ['CCCACAAAAACAA', 'ACTTAAAAACCCA', 'AACCCACAAAAAC', 'AAAAACCATGACC', 'GAGCAAAAACCAA', 'ACATTTATAAAAG', 'ATTTATAAAAGAG', 'CCGCAAAAACCAG']
# 968
# ['AAACAGACGAAAA', 'CCTACAAAAAACT', 'AAAAACCCACAAA', 'TAAAAACCCACAA', 'ATCCCAAATAAAA', 'AAACCAAAATCCC', 'AAACATTTATAAA', 'AAAAAACAGACGA']
# 969
# ['ACTTAAAAACCCA', 'CCAACAAAACCAG', 'AACCCACAAAAAC', 'AACCCACAAAAAA', 'CCAAAATCCCAAA', 'AACCAAAATCCCA', 'TTATAAAAGAGCA', 'CCGCAAAAACCAG']
# 970
# ['AAAACAGACGAAA', 'AAAACCAGCCCCA', 'CGAAAAACTTAAA', 'AAAAACCCACAAA', 'ATAAAAGAGCAAA', 'CCCAAATAAAAAC', 'TCCCAAATAAAAA', 'AAAACACACAAAA']
# 971
# ['CAAAAACAATCAA', 'AAAAAACTTAAAA', 'AGCAGACGAAAAA', 'ACCCACAAAAAAC', 'CCAAATAAAAACC', 'AAAATCCCAAATA', 'TATAAAAGAGCAA', 'ACTTAAAAACACA']
# 972
# ['AGACGAAAAACTT', 'AACCCACAAAAAC', 'AAAAGCAGACGAA', 'AAAAACTTAAAAA', 'TCCCAAATAAAAA', 'AGCAAAAACCAAA', 'AACTAAGATCCCA', 'CACAAAAACCGCA']
# 973
# ['TTAAAAACCCACA', 'TAAAAACCCACAA', 'AACTTAAAAACCC', 'CATGACCAGGAAC', 'AAAAACCAAAATC', 'AAAATCCCAAATA', 'ATAAAAGAGCAAA', 'AAAAACACACAAA']
# 974
# ['AAAACAATCAAAA', 'AAAAACTTAAAAA', 'ACCATCAAAACCA', 'AAAACCATGACCA', 'AACATTTATAAAA', 'AAAAGAGCAAAAA', 'TATAAAAGAGCAA', 'AAACAGACGAAAA']
# 975
# ['AAACTTAAAAACC', 'AAACTTAAAAACC', 'AAAAGCAGACGAA', 'AACCATGACCAGG', 'GAGCAAAAACCAA', 'ATAAAAGAGCAAA', 'GATCCCAAATAAA', 'CACAAAAACCGCA']
# 976
# ['AGACGAAAAACTT', 'ACCAACAAAACCA', 'AAAAGCAGACGAA', 'AAAACCATGACCA', 'AAACCAAAATCCC', 'AAATAAAAACCCA', 'TCCCAAATAAAAA', 'CAAAAACCGCAAA']
# 977
# ['AAAACAATCAAAA', 'CAAAAAACTTAAA', 'GACGAAAAACTTA', 'GAAAAACTTAAAA', 'AAACCAAAATCCC', 'CATTTATAAAAGA', 'AAAGAGCAAAAAC', 'TTAAAAACACACA']
# 978
# ['GAAAAACTTAAAA', 'AAAACTTAAAAAC', 'AAAACCATCAAAA', 'AAAACCCACAAAA', 'AATAAAAACCCAC', 'ATAAAAACCCACA', 'AAAGAGCAAAAAC', 'GCAAAAACCAGCC']
# 979
# ['AAAAAACAGACGA', 'CAACAAAACCAGC', 'CCATCAAAACCAG', 'AACTTAAAAACCC', 'CAAAATCCCAAAT', 'ACATTTATAAAAG', 'AGAGCAAAAACTA', 'AAAACCGCAAAAA']
# 980
# ['CAGACGAAAAACT', 'ACCCACAAAAACC', 'AAAAAGCAGACGA', 'AAACCCACAAAAA', 'TTTATAAAAGAGC', 'CCAAAATCCCAAA', 'AACTAAGATCCCA', 'GCAAAAACCAGCC']
# 981
# ['CAGACGAAAAACT', 'AACCCACAAAAAC', 'GACGAAAAACTTA', 'ACACAAGAAAAAC', 'CATTTATAAAAGA', 'AATCCCAAATAAA', 'ATCCCAAATAAAA', 'CAAAAACCGCAAA']
# 982
# ['CTTAAAAACCCAC', 'AAACCTACAAAAA', 'AAAAACCCACAAA', 'CACAAGAAAAACT', 'AAATCCCAAATAA', 'AAAAACCAAAATC', 'AATAAAAACCCAC', 'GACGAAAAACTTA']
# 983
# ['AAAACTTAAAAAC', 'CCTACAAAAAACT', 'CTTAAAAACCCAC', 'ACCCACAAAAAAC', 'AACATTTATAAAA', 'ACATTTATAAAAG', 'AAATAAAAACCCA', 'ACACACAAAAACC']
# 984
# ['ACAGACGAAAAAC', 'ACAAAAACCAACA', 'AACTTAAAAACCC', 'AACTTAAAAACCC', 'AGAGCAAAAACCA', 'CCAAAATCCCAAA', 'CATTTATAAAAGA', 'AAAAACAGACGAA']
# 985
# ['AAAACTTAAAAAC', 'AAAACTTAAAAAC', 'AACCCACAAAAAC', 'CAAAAAACCATGA', 'GCAAAAACCAAAA', 'TATAAAAGAGCAA', 'TTTATAAAAGAGC', 'TAAAAACACACAA']
# 986
# ['AAAACAATCAAAA', 'AAAAACCAACAAA', 'TTAAAAACCCACA', 'AAAAACTTAAAAA', 'AAACCAAAATCCC', 'ATTTATAAAAGAG', 'AACTAAGATCCCA', 'AAACCGCAAAAAC']
# 987
# ['AAAAACTTAAAAA', 'ACCAACAAAACCA', 'CACAAAAACCATC', 'ACAAAAAACCATG', 'ATCCCAAATAAAA', 'AGCAAAAACCAAA', 'AATAAAAACCCAC', 'CACAAAAACCGCA']
# 988
# ['ACAGACGAAAAAC', 'AAAAACCAACAAA', 'AAACCCACAAAAA', 'AACTTAAAAACCC', 'AAAATCCCAAATA', 'AAAATCCCAAATA', 'CATTTATAAAAGA', 'AAAACAGACGAAA']
# 989
# ['AAACAATCAAAAC', 'ACCCACAAAAACC', 'ACAAAAACCATCA', 'TTAAAAACCCACA', 'TATAAAAGAGCAA', 'TCCCAAATAAAAA', 'CCAAATAAAAACC', 'AACCGCAAAAACC']
# 990
# ['ACAGACGAAAAAC', 'AAAACCCACAAAA', 'ACAAAAACCATCA', 'AAAAACCATGACC', 'CATTTATAAAAGA', 'ATCCCAAATAAAA', 'CAAAAACTAAGAT', 'ACGAAAAACTTAA']
# 991
# ['GACGAAAAACTTA', 'AAACCCACAAAAA', 'AAACTTAAAAACC', 'CATGACCAGGAAC', 'AAAATCCCAAATA', 'GCAAAAACCAAAA', 'AATAAAAACCCAC', 'AAACAGACGAAAA']
# 992
# ['CAATCAAAACCAG', 'CTACAAAAAACTT', 'AAAAGCAGACGAA', 'CCATGACCAGGAA', 'ATTTATAAAAGAG', 'CCCAAATAAAAAC', 'AAGATCCCAAATA', 'ACACAAAAACCGC']
# 993
# ['CAGACGAAAAACT', 'AAACCAACAAAAC', 'CCATCAAAACCAG', 'AAAAACCCACAAA', 'AAACCAAAATCCC', 'GAGCAAAAACCAA', 'ATAAAAACCCACA', 'ACAGACGAAAAAC']
# 994
# ['AAACAATCAAAAC', 'AACCTACAAAAAA', 'CAGACGAAAAACT', 'AAACCATGACCAG', 'TAAAAGAGCAAAA', 'TAAAAGAGCAAAA', 'CTAAGATCCCAAA', 'AAAACAGACGAAA']
# 995
# ['ACAGACGAAAAAC', 'CAAAAACCAACAA', 'TTAAAAACCCACA', 'ACCCACAAAAAAC', 'ATAAAAACCCACA', 'AATCCCAAATAAA', 'AGATCCCAAATAA', 'ACTTAAAAACACA']
# 996
# ['AAAACCCACAAAA', 'AAACTTAAAAACC', 'AAAAACTTAAAAA', 'AACTTAAAAACCC', 'CATTTATAAAAGA', 'GAGCAAAAACCAA', 'ATTTATAAAAGAG', 'CACAAAAACCGCA']
# 997
# ['ACAATCAAAACCA', 'AACCTACAAAAAA', 'CAAAAAGCAGACG', 'CAAAAAACCATGA', 'TTTATAAAAGAGC', 'CGAAACATTTATA', 'ATAAAAGAGCAAA', 'AAAAACCGCAAAA']
# 998
# ['CAAAAACAATCAA', 'ACAAAAACCAACA', 'AAAAACCATCAAA', 'AACCCACAAAAAA', 'AACCAAAATCCCA', 'CCAAAATCCCAAA', 'CAAAAACTAAGAT', 'ACAGACGAAAAAC']
# 999
# ['GACGAAAAACTTA', 'AAAAAACTTAAAA', 'CAAAAAGCAGACG', 'ACTTAAAAACCCA', 'TTTATAAAAGAGC', 'GAAACATTTATAA', 'AAAAGAGCAAAAA', 'AAAAACAGACGAA']

# %% [markdown]
# # Inspection intro

# %% [markdown]
# What data structure did you use to hold your sequence motifs (DNA)?
#
# Is your profile structure based on counts or frequencies?
#
# Where did you implement iterations (mostly why did you choose this)?
#
# If you implemented Gibbs Sampling, how did you implement recomputing of the profile and motif?

# %% [markdown]
# # Inspection Results

# %%
k = ['CTTAAAAACCCAC', 'CTTAAAAACCCAC', 'CTTAAAAACCCAC', 'CTTAAAAACCCAC', 'AATAAAAACCCAC', 'AATAAAAACCCAC', 'AATAAAAACCCAC', 'CTTAAAAACACAC']

# %%
k = dict({
    'A':[1,2,3],
    'B':[4,3,1]})

# %%
v = list(k.values())
k = list(k.keys())
k[v.index(max(v))]
# Out:
# 'B'

# %%
values.index(max(values))
